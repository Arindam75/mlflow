# %%
import mlflow
import mlflow.keras
import os

# %% [markdown]
# Loading data pertaining to an experiment

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.search_runs(experiment_names = ["keras_log"])
# Out:
#                              run_id experiment_id    status  \
# 0  194dff3ecf6e4a8089316769478a7c55             1  FINISHED
# 1  768ce3be6d84489c8b78bfe16f46f153             1  FINISHED
# 2  1d7e8adcea4246dba813cbdd9b10aeda             1  FINISHED
# 3  4e9e4046ea194ddda691966a045a3a62             1  FINISHED
#
#                                         artifact_uri  \
# 0  file:///C:/Users/arind/Documents/mlflow/mlruns...
# 1  file:///C:/Users/arind/Documents/mlflow/mlruns...
# 2  file:///C:/Users/arind/Documents/mlflow/mlruns...
# 3  file:///C:/Users/arind/Documents/mlflow/mlruns...
#
#                         start_time                         end_time  \
# 0 2024-06-30 15:33:47.820000+00:00 2024-06-30 15:34:02.606000+00:00
# 1 2024-06-30 14:37:50.780000+00:00 2024-06-30 14:37:53.395000+00:00
# 2 2024-06-30 13:29:04.072000+00:00 2024-06-30 13:29:33.562000+00:00
# 3 2024-06-30 13:25:45.288000+00:00 2024-06-30 13:27:15.334000+00:00
#
# ...

# %% [markdown]
# Using any of the run_ids we can load a model

# %%
run_relative_path_to_model="model"
run_id = "194dff3ecf6e4a8089316769478a7c55"
model_uri = f"runs:/{run_id}/{run_relative_path_to_model}"

# %%
model = mlflow.keras.load_model(model_uri)

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 512)               401920
#
#  dense_7 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
